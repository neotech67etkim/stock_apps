# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
import seaborn as sns
import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)

# %%
df_red =pd.read_csv('data/red.csv',sep=';')
df_white =pd.read_csv('data/white.csv',sep=';')

# %%
df_red['color'] = 0
df_white['color'] = 1

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  color                 1599 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 162.5 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  color                 4898 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 497.6 KB

# %%
df=pd.concat([df_red,df_white],ignore_index=True)

# %%
dataset = df.values
X = dataset[:,:12]
Y = dataset[:,12]

# %%
model = Sequential()

model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12,activation = 'relu'))
model.add(Dense(8,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))

model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X,Y,batch_size=100,epochs=200)
# Out:
# Epoch 1/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.8392
# Epoch 2/200
# 65/65 [==============================] - 0s 951us/step - loss: 0.2141 - accuracy: 0.9278
# Epoch 3/200
# 65/65 [==============================] - 0s 918us/step - loss: 0.1932 - accuracy: 0.9349
# Epoch 4/200
# 65/65 [==============================] - 0s 868us/step - loss: 0.1855 - accuracy: 0.9366
# Epoch 5/200
# 65/65 [==============================] - 0s 933us/step - loss: 0.1799 - accuracy: 0.9366
# Epoch 6/200
# 65/65 [==============================] - 0s 939us/step - loss: 0.1743 - accuracy: 0.9378
# Epoch 7/200
# 65/65 [==============================] - 0s 896us/step - loss: 0.1684 - accuracy: 0.9404
# Epoch 8/200
# 65/65 [==============================] - 0s 896us/step - loss: 0.1593 - accuracy: 0.9420
# Epoch 9/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1380 - accuracy: 0.9514
# Epoch 10/200
# ...

# %%
X
# Out:
# array([[ 7.4 ,  0.7 ,  0.  , ...,  0.56,  9.4 ,  5.  ],
#        [ 7.8 ,  0.88,  0.  , ...,  0.68,  9.8 ,  5.  ],
#        [ 7.8 ,  0.76,  0.04, ...,  0.65,  9.8 ,  5.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]])

# %%
df_red.iloc[2,:12].values
# Out:
# [array([7.80e+00, 7.60e-01, 4.00e-02, 2.30e+00, 9.20e-02, 1.50e+01,
#         5.40e+01, 9.97e-01, 3.26e+00, 6.50e-01, 9.80e+00, 5.00e+00])]

# %%
test_x = [[7.80e+00, 7.60e-01, 4.00e-02, 2.30e+00, 9.20e-02, 1.50e+01,
        5.40e+01, 9.97e-01, 3.26e+00, 6.50e-01, 9.80e+00, 5.00e+00]]

# %%
model.predict(test_x)
# Out:
# array([[4.9774222e-05]], dtype=float32)
